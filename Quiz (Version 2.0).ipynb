# %% [markdown]
# 3RD VERSION 2.0
# The question are randomly generated.

# %%
import random as rand

### Question Section

def que1():
    print("\nQuestions 1")
    print("A: Option 1")
    print("B: Option 2")
    print("C: Option 3")
    print("D: Option 4")
    
    Ans1 = input("Enter your Answer (i.e A/B/C/D)")
    global Score
    
    match Ans1:
        case "A":
            print("Correct")
            Score += 100
            print (f"Score: {Score}pts")
        case "B":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "C":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "D":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case _:
            print("\nInvalid Input")
            print("You have enter an Invalid Option")
            Score = que1 ()
    return Score

def que2():
    print("\nQuestions 2")
    print("A: Option 1")
    print("B: Option 2")
    print("C: Option 3")
    print("D: Option 4")

    Ans2 = input("Enter your Answer (i.e A/B/C/D)") 
    global Score
    
    match Ans2:
        case "A":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "B":
            print("Correct")
            Score += 100
            print (f"Score: {Score}pts")
        case "C":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "D":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case _:
            print("\nInvalid Input")
            print("You have enter an Invalid Option")
            Score = que2 ()
    return Score

def que3():
    print("\nQuestions 3")
    print("A: Option 1")
    print("B: Option 2")
    print("C: Option 3")
    print("D: Option 4")

    Ans3 = input("Enter your Answer (i.e A/B/C/D)") 
    global Score
    
    match Ans3:
        case "A":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "B":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "C":
            print("Correct")
            Score += 100
            print (f"Score: {Score}pts")
        case "D":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case _:
            print("\nInvalid Input")
            print("You have enter an Invalid Option")
            Score = que3 ()
    return Score

def que4():
    print("\nQuestions 4")
    print("A: Option 1")
    print("B: Option 2")
    print("C: Option 3")
    print("D: Option 4")

    Ans4 = input("Enter your Answer (i.e A/B/C/D)") 
    global Score
    
    match Ans4:
        case "A":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "B":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "C":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "D":
            print("Correct")
            Score += 100
            print (f"Score: {Score}pts")
        case _:
            print("\nInvalid Input")
            print("You have enter an Invalid Option")
            Score = que4 ()
    return

def que5():
    print("\nQuestions 5")
    print("A: Option 1")
    print("B: Option 2")
    print("C: Option 3")
    print("D: Option 4")

    Ans5 = input("Enter your Answer (i.e A/B/C/D)") 
    global Score
    
    match Ans5:
        case "A":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "B":
            print("Correct")
            Score += 100
            print (f"Score: {Score}pts")
        case "C":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "D":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case _:
            print("\nInvalid Input")
            print("You have enter an Invalid Option")
            Score = que5 ()
    return Score

### Question Generator

def queGenerator (id):
    queNum = id
    
    if queNum == 1:
        Score = que1()
    
    elif queNum == 2:
        Score = que2()

    elif queNum == 3:
        Score = que3()

    elif queNum == 4:
        Score = que4()

    elif queNum == 5:
        Score = que5()

    else:
        pass
    
    return Score


    
### Quiz Question Section


def quiz1 ():
    print("\nQUESTION 1")
    queId = rand.randint(1, 5)
    
    Score = queGenerator (queId)
    
    return Score

def quiz2 (Score):
    print("\nQUESTION 2")
    queId = rand.randint(1, 5)
    
    Score = queGenerator (queId)
    
    return Score


#### THE SIMPLE QUIZ SECTION

def quizGame():
    Point = quiz1()
    Point2 = quiz2(Point)
    
    print("\nYour Score BreakDown")
    print(f"Level 1: {Point}")
    print(f"Level 2: {Point2}")

    Final = Point2
    return Final


### Main Section

Score = 0
totalScore = quizGame()

print(f"Total Point: {totalScore}")
# Out:
# QUESTION 1
#
# Questions 2
# A: Option 1
# B: Option 2
# C: Option 3
# D: Option 4
# Enter your Answer (i.e A/B/C/D) A
# Incorrect
# Score: 0pts
#
# QUESTION 2
#
# Questions 2
# A: Option 1
# B: Option 2
# C: Option 3
# D: Option 4
# Enter your Answer (i.e A/B/C/D) B
# Correct
# Score: 100pts
#
# Your Score BreakDown
# Level 1: 0
# Level 2: 100
# Total Point: 100
