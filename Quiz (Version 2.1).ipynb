# %%
import random as rand

### Question Section

def que1():
    print("\nWhich of the following is the correct way to declare a variable in Python?")
    print("A: x = 10")
    print("B: int x = 10;")
    print("C: var x = 10;")
    print("D: declare x = 10;")
    
    Ans1 = input("Enter your Answer (i.e A/B/C/D)")
    global Score
    
    match Ans1:
        case "A":
            print("Correct")
            Score += 100
            print (f"Score: {Score}pts")
        case "B":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "C":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "D":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case _:
            print("\nInvalid Input")
            print("You have enter an Invalid Option")
            Score = que1 ()
    return Score

def que2():
    print("\nWhich of the following is a loop structure in Python?")
    print("A: if")
    print("B: while")
    print("C: def")
    print("D: print")

    Ans2 = input("Enter your Answer (i.e A/B/C/D)") 
    global Score
    
    match Ans2:
        case "A":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "B":
            print("Correct")
            Score += 100
            print (f"Score: {Score}pts")
        case "C":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "D":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case _:
            print("\nInvalid Input")
            print("You have enter an Invalid Option")
            Score = que2 ()
    return Score

def que3():
    print("\nWhich of the following is used to define a function in Python?")
    print("A: function")
    print("B: void")
    print("C: def")
    print("D: define")

    Ans3 = input("Enter your Answer (i.e A/B/C/D)") 
    global Score
    
    match Ans3:
        case "A":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "B":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "C":
            print("Correct")
            Score += 100
            print (f"Score: {Score}pts")
        case "D":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case _:
            print("\nInvalid Input")
            print("You have enter an Invalid Option")
            Score = que3 ()
    return Score

def que4():
    print("\nWhat is the purpose of the return statement in a function?")
    print("A: It ends the program.")
    print("B: It exits the loop")
    print("C: It continues the loop")
    print("D: It outputs a value from a function")

    Ans4 = input("Enter your Answer (i.e A/B/C/D)") 
    global Score
    
    match Ans4:
        case "A":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "B":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "C":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "D":
            print("Correct")
            Score += 100
            print (f"Score: {Score}pts")
        case _:
            print("\nInvalid Input")
            print("You have enter an Invalid Option")
            Score = que4 ()
    return

def que5():
    print("\nWhich of the following is the correct way to start a comment in Python?")
    print("A: // This is a comment")
    print("B: # This is a comment")
    print("C: /* This is a comment */")
    print("D: <!-- This is a comment -->")

    Ans5 = input("Enter your Answer (i.e A/B/C/D)") 
    global Score
    
    match Ans5:
        case "A":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "B":
            print("Correct")
            Score += 100
            print (f"Score: {Score}pts")
        case "C":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case "D":
            print("Incorrect")
            Score += 0
            print (f"Score: {Score}pts")
        case _:
            print("\nInvalid Input")
            print("You have enter an Invalid Option")
            Score = que5 ()
    return Score

### Question Generator

def queGenerator (id):
    queNum = id
    
    if queNum == 1:
        Question = que1()
    
    elif queNum == 2:
        Question = que2()

    elif queNum == 3:
        Question = que3()

    elif queNum == 4:
        Question = que4()

    elif queNum == 5:
        Question = que5()

    else:
        pass
    
    return Question


    
### Quiz Question Section


def quiz1 ():
    print("\nQUESTION 1")
    queId = rand.randint(1, 5)
    
    Score = queGenerator (queId)
    
    return Score

def quiz2 (Score):
    print("\nQUESTION 2")
    queId = rand.randint(1, 5)
    
    Score = queGenerator (queId)
    
    return Score


#### THE SIMPLE QUIZ SECTION

def quizGame():
    
    Point = quiz1()
    
    while Point == 0:
        print("\nGame Over ReStarting.........................")
        Point = quiz1()

    Point2 = quiz2(Point)
    
    if Point2 == 100:
        print("\nGame Over ReStarting.........................")
        Point2 = quizGame()
   
    else:
        print("\nYour Score BreakDown")
        print(f"Level 1: {Point}")
        print(f"Level 2: {Point2}")

    Final = Point2
    
    return Final


### Main Section

Score = 0
totalScore = quizGame()

print(f"Total Point: {totalScore}")
# Out:
# QUESTION 1
#
# Which of the following is used to define a function in Python?
# A: function
# B: void
# C: def
# D: define
# Enter your Answer (i.e A/B/C/D) C
# Correct
# Score: 100pts
#
# QUESTION 2
#
# Which of the following is used to define a function in Python?
# A: function
# B: void
# C: def
# D: define
# Enter your Answer (i.e A/B/C/D) A
# Incorrect
# Score: 100pts
#
# Game Over ReStarting.........................
#
# QUESTION 1
#
# Which of the following is the correct way to start a comment in Python?
# A: // This is a comment
# B: # This is a comment
# C: /* This is a comment */
# D: <!-- This is a comment -->
# Enter your Answer (i.e A/B/C/D) B
# Correct
# Score: 200pts
#
# QUESTION 2
#
# Which of the following is used to define a function in Python?
# A: function
# B: void
# C: def
# D: define
# Enter your Answer (i.e A/B/C/D) C
# Correct
# Score: 300pts
#
# Your Score BreakDown
# Level 1: 200
# Level 2: 300
# Total Point: 300

# %% [markdown]
# #
